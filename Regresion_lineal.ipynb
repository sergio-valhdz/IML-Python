# %% [markdown]
# # Scikit Learn

# %% [markdown]
# Paquete de machine learning más popular. Tiene muchos algoritmos, pre-construidos.

# %% [markdown]
# ## Para trabajar

# %% [markdown]
# -Importamos el modulo
# -Inicializamos los parámetros
# -Los datos disponibles se dividen datos de entrenamiento y datos de prueba(train_test_split)
# -Entrenar el modelo con los datos de entrenamiento
# -Predecir las etiquetas o valores para los datos.
# -Evaluar el modelo, comparando nuestras predicciones con los valores correctos de los datos de prueba

# %% [markdown]
# # Regresión lineal

# %% [markdown]
# Algoritmo de aprendizaje supervisado. Dibuja una recta para indicar la tendencia de los valores

# %% [markdown]
# ## Ejemplo con Python

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# ### Obtención de los data sets

# %% [markdown]
# La pagina kaggle.com cuenta con una gran cantidad de data sets para probar nuestros modelos. Para este ejemplo usaremos USA_Housing.csv
# Haremos un modelo de regresion lineal con estos datos

# %%
cd data_sets
# Out:
# c:\Users\NüVO Gamer Station\Documents\Programacion\Python\Udemy Machine Free\data_sets

# %%
ls
# Out:
#  El volumen de la unidad C no tiene etiqueta.
#  El n�mero de serie del volumen es: 08A0-3195
#
#  Directorio de c:\Users\N�VO Gamer Station\Documents\Programacion\Python\Udemy Machine Free\data_sets
#
# 08/12/2020  04:00 p. m.    <DIR>          .
# 08/12/2020  04:00 p. m.    <DIR>          ..
# 08/12/2020  03:56 p. m.           371,432 archive.zip
# 25/09/2019  08:26 a. m.           726,209 USA_Housing.csv
#                2 archivos      1,097,641 bytes
#                2 dirs  105,928,482,816 bytes libres

# %%
casas = pd.read_csv('USA_Housing.csv')
casas
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population         Price  \
# ...

# %%
casas.head(20)
# Out:
#     Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0       79545.458574             5.682861                   7.009188
# 1       79248.642455             6.002900                   6.730821
# 2       61287.067179             5.865890                   8.512727
# 3       63345.240046             7.188236                   5.586729
# 4       59982.197226             5.040555                   7.839388
# 5       80175.754159             4.988408                   6.104512
# 6       64698.463428             6.025336                   8.147760
# 7       78394.339278             6.989780                   6.620478
# 8       59927.660813             5.362126                   6.393121
# 9       81885.927184             4.423672                   8.167688
# 10      80527.472083             8.093513                   5.042747
# 11      50593.695497             4.496513                   7.467627
# 12      39033.809237             7.671755                   7.250029
# ...

# %%
casas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 7 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Avg. Area Income              5000 non-null   float64
#  1   Avg. Area House Age           5000 non-null   float64
#  2   Avg. Area Number of Rooms     5000 non-null   float64
#  3   Avg. Area Number of Bedrooms  5000 non-null   float64
#  4   Area Population               5000 non-null   float64
#  5   Price                         5000 non-null   float64
#  6   Address                       5000 non-null   object
# dtypes: float64(6), object(1)
# memory usage: 254.0+ KB

# %%
casas.describe()
# Out:
#        Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# count       5000.000000          5000.000000                5000.000000
# mean       68583.108984             5.977222                   6.987792
# std        10657.991214             0.991456                   1.005833
# min        17796.631190             2.644304                   3.236194
# 25%        61480.562388             5.322283                   6.299250
# 50%        68804.286404             5.970429                   7.002902
# 75%        75783.338666             6.650808                   7.665871
# max       107701.748378             9.519088                  10.759588
#
#        Avg. Area Number of Bedrooms  Area Population         Price
# count                   5000.000000      5000.000000  5.000000e+03
# mean                       3.981330     36163.516039  1.232073e+06
# std                        1.234137      9925.650114  3.531176e+05
# ...

# %%
casas.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
casas['Price']
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 5000, dtype: float64

# %%
sns.distplot(casas['Price'])
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %%
sns.heatmap(casas.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
casas.head()
# Out:
#    Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0      79545.458574             5.682861                   7.009188
# 1      79248.642455             6.002900                   6.730821
# 2      61287.067179             5.865890                   8.512727
# 3      63345.240046             7.188236                   5.586729
# 4      59982.197226             5.040555                   7.839388
#
#    Avg. Area Number of Bedrooms  Area Population         Price  \
# 0                          4.09     23086.800503  1.059034e+06
# 1                          3.09     40173.072174  1.505891e+06
# 2                          5.13     36882.159400  1.058988e+06
# 3                          3.26     34310.242831  1.260617e+06
# 4                          4.23     26354.109472  6.309435e+05
#
#                                              Address
# 0  208 Michael Ferry Apt. 674\nLaurabury, NE 3701...
# 1  188 Johnson Views Suite 079\nLake Kathleen, CA...
# ...

# %%
casas.columns
# Out:
# Index(['Avg. Area Income', 'Avg. Area House Age', 'Avg. Area Number of Rooms',
#        'Avg. Area Number of Bedrooms', 'Area Population', 'Price', 'Address'],
#       dtype='object')

# %%
X = casas[['Avg. Area Income','Avg. Area House Age', 'Avg. Area Number of Rooms', 'Avg. Area Number of Bedrooms', 'Area Population']]

# %%
X
# Out:
#       Avg. Area Income  Avg. Area House Age  Avg. Area Number of Rooms  \
# 0         79545.458574             5.682861                   7.009188
# 1         79248.642455             6.002900                   6.730821
# 2         61287.067179             5.865890                   8.512727
# 3         63345.240046             7.188236                   5.586729
# 4         59982.197226             5.040555                   7.839388
# ...                ...                  ...                        ...
# 4995      60567.944140             7.830362                   6.137356
# 4996      78491.275435             6.999135                   6.576763
# 4997      63390.686886             7.250591                   4.805081
# 4998      68001.331235             5.534388                   7.130144
# 4999      65510.581804             5.992305                   6.792336
#
#       Avg. Area Number of Bedrooms  Area Population
# 0                             4.09     23086.800503
# ...

# %%
Y = casas['Price']

# %%
Y
# Out:
# 0       1.059034e+06
# 1       1.505891e+06
# 2       1.058988e+06
# 3       1.260617e+06
# 4       6.309435e+05
#             ...
# 4995    1.060194e+06
# 4996    1.482618e+06
# 4997    1.030730e+06
# 4998    1.198657e+06
# 4999    1.298950e+06
# Name: Price, Length: 5000, dtype: float64

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3,random_state=42)

# %%
lrm = LinearRegression()
lrm.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
from sklearn import metrics

# %%
predicciones = lrm.predict(X_test)

# %%
predicciones
# Out:
# array([1308536.1359262 , 1237122.72746477, 1243835.62817066, ...,
#        1457119.79297242, 1483428.9530937 , 1047510.59737176])

# %%
Y_test
# Out:
# 1501    1.339096e+06
# 2586    1.251794e+06
# 2653    1.340095e+06
# 1055    1.431508e+06
# 705     1.042374e+06
#             ...
# 3563    1.348222e+06
# 1538    1.309937e+06
# 1837    1.472887e+06
# 2380    1.409762e+06
# 1912    1.009606e+06
# Name: Price, Length: 1500, dtype: float64

# %%
plt.scatter(Y_test, predicciones)

# %%
sns.distplot(Y_test-predicciones)
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# MAE (Mean Absolute Error) -> Media del valor absoluto de los errores

# %%
metrics.mean_absolute_error(Y_test,predicciones)
# Out:
# 81135.56609336878

# %% [markdown]
# MSE (Media de los errores al cuadrado)

# %%
metrics.mean_squared_error(Y_test,predicciones)
# Out:
# 10068422551.401085

# %% [markdown]
# RMSE (Raiz cuadradad de la media de los errores al cuadrado)

# %%
np.sqrt(metrics.mean_squared_error(Y_test,predicciones))
# Out:
# 100341.52954485538
